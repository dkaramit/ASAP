# %% [markdown]
# I wrote SGD in the form of a module, just to be able to add more algorithms and test it easiy.
#
# This is how it works

# %%
import numpy as np


import matplotlib
matplotlib.use('nbAgg')
import matplotlib.pyplot as plt

# %%
import SGD

# %%
def testFunc(self,x):
    return [x[0]*self.w[0]+ self.w[1]]

def SME_loss(f,x,t):
    return np.mean([(f(x)[i] -  1/(f(x)[i]) )**2 for i,_t in enumerate(t)])

# %%
f=SGD.targetFunc(testFunc,[1,3])
Q=SGD.lossFunc(SME_loss,f)


data=[]
xmin=-1
xmax=1
for i in range(500):
    x=np.random.rand()*(xmax-xmin)+xmin
    data.append( [[x],[0]])

# strategy=SGD.VanillaSGD(Q ,data,alpha=1e-2)
# strategy=SGD.RMSpropSGD(Q ,data,gamma=1-1e-2,epsilon=1e-5,alpha=1e-2)
# strategy=SGD.AdaDeltaSGD(Q ,data,gamma=0.99,epsilon=1e-5,alpha=1)
# strategy=SGD.AdamSGD(Q ,data,beta_m=0.95,beta_v=0.999,epsilon=1e-8,alpha=1e-2)
# strategy=SGD.AdaMaxSGD(Q ,data,beta_m=0.95,beta_v=0.999,epsilon=1e-8,alpha=1e-2)
strategy=SGD.NAdamSGD(Q ,data,beta_m=0.95,beta_v=0.999,epsilon=1e-8,alpha=1e-2)


sgd=SGD.StochasticGradientDescent(strategy)
w=sgd.run(abs_tol=1e-5, rel_tol=1e-5, step_break=250,max_step=5000)
print('w=',w,'\nNo steps',len(strategy.steps),' mean error, Q=',np.mean([Q(x,y) for x,y in data]))
# Out:
# w= [-1.8284503038635784e-09, 1.0000000004869811]
# No steps 896  mean error, Q= 5.653813104672207e-18

# %%
fig=plt.figure(figsize=(8,6))
fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.1,hspace=0)
#=============================================================================#


sub = fig.add_subplot(211)
sub.get_xaxis().set_visible(False)

sub.plot(np.array(strategy.steps)[:,0],c='xkcd:black')
sub.plot(np.array(strategy.steps)[:,1],c='xkcd:red')

sub.set_ylabel('x')
# sub.set_xscale('log')
sub.set_yscale('linear')


sub = fig.add_subplot(212)
meanQ=[]
steps=[]
_s=0
skip=100
for w in strategy.steps[::skip]:
    f.w=w
    mQ=0
    _r=range(len(data))
    mC=50
    for _ in range(mC): 
        i=np.random.choice(_r)
        mQ+=Q(data[i][0], data[i][1]) 
    meanQ.append(mQ/mC)
    steps.append(_s)
    _s+=skip
    
sub.plot(steps,meanQ,c='xkcd:black')

sub.set_ylabel('Mean of $Q$')

# sub.set_xscale('log')
sub.set_yscale('log')

sub.set_xlabel('Step')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
