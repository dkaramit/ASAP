# %%
import os,subprocess,sys,time

# %%
import numpy as np

import matplotlib
matplotlib.use('nbAgg')
import matplotlib.pyplot as plt

# %%
# %%sh
# make
# Out:
# g++ -o "/media/200Gb/programming_numerics/ASAP/Optimization/Minimization/Gradient-Descent/C++/simple_GD.run" "/media/200Gb/programming_numerics/ASAP/Optimization/Minimization/Gradient-Descent/C++/simple_GD.cpp" -std=c++17  -I "/media/200Gb/programming_numerics/ASAP/Optimization/Minimization/Gradient-Descent/C++"  -lm   -O3 -DLONG=  -Wall

# %%
time0=time.time()

_cpp=subprocess.check_output(["./simple_GD.run"]).decode(sys.stdout.encoding)

time.time()-time0
# Out:
# 0.03133249282836914

# %%
steps=np.array([_.split(' ') for _ in _cpp.split("\n")[:-3]],dtype=np.float)

x,minimum=[np.array(_.split(' '),dtype=np.float) for _ in _cpp.split("\n")[-3:-1]]
len(steps),x,minimum
# Out:
# (5075,
#  array([4.93038e-32, 2.00000e+00, 1.00000e+00]),
#  array([4.93038e-32, 2.00000e+00, 1.00000e+00]))

# %%
fig=plt.figure(figsize=(8,6))
fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.1,hspace=0)
#=============================================================================#


sub = fig.add_subplot(211)
sub.get_xaxis().set_visible(False)

sub.plot(steps[:,1:])

sub.set_ylabel('x')
# sub.set_xscale('log')
sub.set_yscale('linear')

sub = fig.add_subplot(212)
# sub.get_xaxis().set_visible(False)


sub.plot(steps[:,0] ,c='xkcd:black')

sub.set_ylabel('f(x)')
sub.set_xlabel('step')
sub.set_yscale('log')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
