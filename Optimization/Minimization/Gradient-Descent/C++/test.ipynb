# %%
import os,subprocess,sys,time

# %%
import numpy as np

import matplotlib
matplotlib.use('nbAgg')
import matplotlib.pyplot as plt

# %%
# %%sh
# make
# Out:
# make: Nothing to be done for 'all'.

# %%
time0=time.time()

_cpp=subprocess.check_output(["./simple_GD.run"]).decode(sys.stdout.encoding)

time.time()-time0
# Out:
# 0.04625749588012695

# %%
steps=np.array([_.split(' ') for _ in _cpp.split("\n")[:-3]],dtype=np.float)

x,minimum=[np.array(_.split(' '),dtype=np.float) for _ in _cpp.split("\n")[-3:-1]]
len(steps),x,minimum
# Out:
# (5062,
#  array([3.14425e-05, 1.99953e+00, 1.20000e+01]),
#  array([1.41394e-08, 1.99993e+00, 1.19991e+01]))

# %%
fig=plt.figure(figsize=(8,6))
fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.1,hspace=0)
#=============================================================================#


sub = fig.add_subplot(211)
sub.get_xaxis().set_visible(False)

sub.plot(steps[:,1:])

sub.set_ylabel('x')
# sub.set_xscale('log')
sub.set_yscale('linear')

sub = fig.add_subplot(212)
# sub.get_xaxis().set_visible(False)


sub.plot(steps[:,0] ,c='xkcd:black')

sub.set_ylabel('f(x)')
sub.set_xlabel('step')
sub.set_yscale('log')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
